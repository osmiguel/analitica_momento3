# %%
import pandas as pd

# %%
datos_viviendas = pd.read_csv("/content/drive/MyDrive/AnaliticaPython/alquileres_viviendas.csv", sep = ";")

# %%
datos_viviendas.head(30)
# Out:
#     Unnamed: 0                Tipo     Distrito  Cuartos  Vacantes  Suites  \
# 0            0          Habitación    San Borja        1         0       0
# 1            1                Casa   Lurigancho        2         0       1
# 2            2        Departamento   Pachacámac        1         0       0
# 3            3        Departamento          Ate        1         0       0
# 4            4        Departamento     Barranco        3         1       0
# 5            5        Departamento        Comas        2         0       0
# 6            6  Casa en condominio          Ate        5         4       5
# 7            7  Casa en condominio  El Agustino        2         2       0
# 8            8        Departamento   Pachacámac        1         0       0
# 9            9        Departamento      Mi Perú        2         1       0
# 10          10        Departamento    San Borja        3         1       1
# ...

# %%
sel_departamento = datos_viviendas["Tipo"] == "Departamento"
cant_departamento = datos_viviendas[sel_departamento].shape[0]
cant_departamento
# Out:
# 19532

# %%
sel_otros_departamento = datos_viviendas["Tipo"] == "Departamento"
cant_otras = datos_viviendas[~sel_otros_departamento].shape[0]
cant_otras
# Out:
# 3658

# %%
sel_casa_hab_coch = (datos_viviendas["Tipo"] == "Casa") | (datos_viviendas["Tipo"] == "Habitación") | (datos_viviendas["Tipo"] == "Cochera")
cant_casa_hab_coch = datos_viviendas[sel_casa_hab_coch].shape[0]
cant_casa_hab_coch
# Out:
# 1885

# %%
sel_area = (datos_viviendas['Area']>=60) & (datos_viviendas['Area']<=100)
cant_viv_area = datos_viviendas[sel_area]
cant_viv_area
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-85c56e326352> in <cell line: 1>()
# ----> 1 sel_area = (datos_viviendas['Area']>=60) & (datos_viviendas['Area']<=100)
#       2 cant_viv_area = datos_viviendas[sel_area]
#       3 cant_viv_area
#
# NameError: name 'datos_viviendas' is not defined

# %%
sel_area = (datos_viviendas['Area']>=60) & (datos_viviendas['Area']<=100)
cant_viv_area = datos_viviendas[sel_area].shape[0]
cant_viv_area
# Out:
# 8990

# %%
sel_hab_precio = (datos_viviendas['Cuartos']>=4) & (datos_viviendas['Valor']<=2000)
cant_hab_precio = datos_viviendas[sel_hab_precio].shape[0]
cant_hab_precio
# Out:
# 62

# %%
print("Se encontraron los siguentes resultados:")
print(f"La cantidad de departamentos es de {cant_departamento}")
print(f"La cantidad de otras viviendas {cant_otras}")
print(f"La cantidad de viviendas tipo Casa, habitación y cochera es de {cant_casa_hab_coch}")
print(f"La cantidad de viviendas con un área de 60 y 100 metros cuadrados es de {cant_viv_area}")
print(f"La cantidad de vivendas con mas de 4 habitaciones y un valor menor o igual a 2000 reales es de{cant_hab_precio}")
# Out:
# Se encontraron los siguentes resultados:
# La cantidad de departamentos es de 19532
# La cantidad de otras viviendas 3658
# La cantidad de viviendas tipo Casa, habitación y cochera es de 1885
# La cantidad de viviendas con un área de 60 y 100 metros cuadrados es de 8990
# La cantidad de vivendas con mas de 4 habitaciones y un valor menor o igual a 2000 reales es de62

# %%
datos_viviendas.isnull()
# Out:
#        Unnamed: 0   Tipo  Distrito  Cuartos  Vacantes  Suites   Area  Valor  \
# 0           False  False     False    False     False   False  False  False
# 1           False  False     False    False     False   False  False  False
# 2           False  False     False    False     False   False  False  False
# 3           False  False     False    False     False   False  False  False
# 4           False  False     False    False     False   False  False  False
# ...           ...    ...       ...      ...       ...     ...    ...    ...
# 23185       False  False     False    False     False   False  False  False
# 23186       False  False     False    False     False   False  False  False
# 23187       False  False     False    False     False   False  False  False
# 23188       False  False     False    False     False   False  False  False
# 23189       False  False     False    False     False   False  False  False
#
#        Mantenimiento  Impuesto
# ...

# %%
datos_viviendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23190 entries, 0 to 23189
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     23190 non-null  int64
#  1   Tipo           23190 non-null  object
#  2   Distrito       23190 non-null  object
#  3   Cuartos        23190 non-null  int64
#  4   Vacantes       23190 non-null  int64
#  5   Suites         23190 non-null  int64
#  6   Area           23190 non-null  int64
#  7   Valor          23181 non-null  float64
#  8   Mantenimiento  21265 non-null  float64
#  9   Impuesto       16254 non-null  float64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 1.8+ MB

# %%
datos_viviendas[datos_viviendas['Valor'].isnull()]
# Out:
#       Unnamed: 0          Tipo     Distrito  Cuartos  Vacantes  Suites  Area  \
# 60            60  Departamento          Ate        2         1       1    70
# 1533        1533  Departamento  San Bartolo        2         0       0    75
# 1727        1727          Casa        Lince        3         4       3   363
# 2065        2065  Departamento   Chorrillos        2         0       0    95
# 2087        2087  Departamento    San Borja        2         0       0    72
# 5083        5083          Casa        Lince        3         2       1   100
# 8813        8813  Departamento  San Bartolo        2         0       1    75
# 9204        9204  Departamento     La Punta        3         0       1   135
# 9410        9410  Departamento     La Perla        3         1       1   105
#
#       Valor  Mantenimiento  Impuesto
# 60      NaN          970.0      68.0
# 1533    NaN          878.0       NaN
# 1727    NaN            NaN       NaN
# 2065    NaN         1010.0     170.0
# ...

# %%
vivienda_nan = datos_viviendas.shape[0]

# %%
vivienda_nan = datos_viviendas.shape[0]
datos_viviendas.dropna(subset=['Valor'],inplace = True)
vivienda_nan_b = datos_viviendas.shape[0]
vivienda_nan - vivienda_nan_b
# Out:
# 9

# %%
datos_viviendas[datos_viviendas['Valor'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Tipo, Distrito, Cuartos, Vacantes, Suites, Area, Valor, Mantenimiento, Impuesto]
# Index: []

# %% [markdown]
# #Cuando la desicion es conservar los datos debemos sobre escribir con un valor, en este caso 0, para conservar la fila.

# %%
datos_viviendas[datos_viviendas['Mantenimiento'].isnull()].shape[0]
# Out:
# 1923

# %%
sel = (datos_viviendas['Tipo'] == 'Departamento') & (datos_viviendas['Mantenimiento'].isnull())

# %%
sel_A = datos_viviendas.shape[0]
datos_viviendas = datos_viviendas[~sel]
datos_viviendas
# Out:
#        Unnamed: 0          Tipo    Distrito  Cuartos  Vacantes  Suites  Area  \
# 0               0    Habitación   San Borja        1         0       0    40
# 1               1          Casa  Lurigancho        2         0       1   100
# 2               2  Departamento  Pachacámac        1         0       0    15
# 3               3  Departamento         Ate        1         0       0    48
# 5               5  Departamento       Comas        2         0       0    50
# ...           ...           ...         ...      ...       ...     ...   ...
# 23185       23185       Cochera  Pachacámac        0         0       0   755
# 23186       23186    Habitación  Pachacámac        0         0       0    27
# 23187       23187  Departamento       Lince        3         1       2    78
# 23188       23188  Departamento       Rímac        2         1       0    48
# 23189       23189  Departamento       Rímac        2         0       0    70
#
#          Valor  Mantenimiento  Impuesto
# ...
