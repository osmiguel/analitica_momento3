# %% [markdown]
# #Analisis de dataframe para nuevas tecnologías.

# %%
import pandas as pd

# %%
info_alquiler = pd.read_csv('/content/drive/MyDrive/AnaliticaPython/alquiler.csv', sep = ';')

# %%
info_alquiler.shape
# Out:
# (32960, 9)

# %% [markdown]
# Head para imprimir los primeros datos del dataframe tabla:head(numero)

# %%
info_alquiler.head(10)
# Out:
#                  Tipo     Distrito  Cuartos  Vacantes  Suites  Area    Valor  \
# 0          Habitación    San Borja        1         0       0    40   1700.0
# 1                Casa   Lurigancho        2         0       1   100   7000.0
# 2     Local comercial          Ate        0         4       0   150   5200.0
# 3        Departamento   Pachacámac        1         0       0    15    800.0
# 4        Departamento          Ate        1         0       0    48    800.0
# 5        Departamento     Barranco        3         1       0    70   1200.0
# 6        Departamento        Comas        2         0       0    50   1300.0
# 7  Casa en condominio          Ate        5         4       5   750  22000.0
# 8  Casa en condominio  El Agustino        2         2       0    65   1000.0
# 9     Local comercial   Pachacámac        0         3       0   695  35000.0
#
#    Mantenimiento  Impuesto
# 0          500.0      60.0
# 1            NaN       NaN
# 2         4020.0    1111.0
# 3          390.0      20.0
# 4          230.0       NaN
# 5            NaN       NaN
# 6          301.0      17.0
# 7            NaN       NaN
# 8            NaN       NaN
# 9        19193.0    3030.0

# %% [markdown]
# Tail para imprimir los ultimos datos del dataframe tabla:head(numero)

# %%
info_alquiler.tail(10)
# Out:
#                      Tipo     Distrito  Cuartos  Vacantes  Suites  Area  \
# 32950        Departamento   San Miguel        1         0       0    28
# 32951        Departamento          Ate        2         0       0    52
# 32952  Casa en condominio          Ate        5         3       4   450
# 32953        Departamento  Santa Anita        2         0       0    70
# 32954             Cochera   Pachacámac        0         0       0   755
# 32955          Habitación   Pachacámac        0         0       0    27
# 32956        Departamento        Lince        3         1       2    78
# 32957        Departamento        Rímac        2         1       0    48
# 32958        Departamento        Rímac        2         0       0    70
# 32959     Local comercial   Pachacámac        0         0       0   250
#
#          Valor  Mantenimiento  Impuesto
# 32950   1000.0          360.0      25.0
# 32951   1000.0          550.0       NaN
# 32952  15000.0         1711.0    2332.0
# 32953    900.0          490.0      48.0
# 32954  14000.0            NaN       NaN
# 32955    800.0          350.0      25.0
# 32956   1800.0          800.0      40.0
# 32957   1400.0          509.0      37.0
# 32958   3000.0          760.0       NaN
# 32959   6500.0         4206.0    1109.0

# %% [markdown]
# Filtrar la información por categoria de una columna.

# %%
list(info_alquiler['Tipo'].drop_duplicates().tail(10))
# Out:
# ['Cochera',
#  'Loft',
#  'Tienda en Centro Comercial',
#  'Chacra',
#  'Terreno em condominio',
#  'Oficina',
#  'Chalet',
#  'Studio',
#  'Hotel',
#  'Local industrial']

# %%
list(info_alquiler['Distrito'].drop_duplicates())
# Out:
# ['San Borja',
#  'Lurigancho',
#  'Ate',
#  'Pachacámac',
#  'Barranco',
#  'Comas',
#  'El Agustino',
#  'Mi Perú',
#  'Chorrillos',
#  'San Luis',
#  'Callao',
#  'San Miguel',
#  'Santa Rosa',
#  'Rímac',
#  'Punta Negra',
#  'Lince',
#  'Jesús María',
#  'Miraflores',
#  'Breña',
#  'Ancón',
#  'Santa Anita',
#  'Villa María del Triunfo',
#  'Villa El Salvador',
#  'Punta Hermosa',
#  'La Perla',
#  'San Juan de Lurigancho',
#  'Chaclacayo',
#  'Pueblo Libre',
#  'Puente Piedra',
#  'Lurín',
#  'La Punta',
#  'Ventanilla',
#  'Magdalena del Mar',
#  'Santa María del Mar',
#  'Bellavista',
#  'San Martín de Porres',
#  'Santiago de Surco',
#  'San Juan de Miraflores',
#  'San Isidro',
#  'San Bartolo',
#  'Carmen de La Legua',
#  'Los Olivos',
#  'Pucusana',
#  'La Molina',
#  'Cieneguilla',
#  'Lima',
#  'Independencia',
#  'Surquillo',
#  'La Victoria',
#  'Carabayllo']

# %%
list(info_alquiler['Tipo'].drop_duplicates().tail(10))
# Out:
# ['Cochera',
#  'Loft',
#  'Tienda en Centro Comercial',
#  'Chacra',
#  'Terreno em condominio',
#  'Oficina',
#  'Chalet',
#  'Studio',
#  'Hotel',
#  'Local industrial']

# %%
viviendas = ['Habitación',
 'Casa',
 'Departamento',
 'Casa en condominio',
 'Flat',
 'Casa de villa',
 'Cochera',
 'Loft',
 'Chalet'
 ]

# %%
viviendas
# Out:
# ['Habitación',
#  'Casa',
#  'Departamento',
#  'Casa en condominio',
#  'Flat',
#  'Casa de villa',
#  'Cochera',
#  'Loft',
#  'Chalet']

# %% [markdown]
# Validar si viviendas esta en info_alquiler

# %%
info_viviendas = info_alquiler['Tipo'].isin(viviendas)

# %%
info_viviendas
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 32955     True
# 32956     True
# 32957     True
# 32958     True
# 32959    False
# Name: Tipo, Length: 32960, dtype: bool

# %% [markdown]
# construir el data frame con los datos de solo viviendas

# %%
datos_viviendas = info_alquiler[info_viviendas]

# %%
datos_viviendas
# Out:
#                Tipo    Distrito  Cuartos  Vacantes  Suites  Area    Valor  \
# 0        Habitación   San Borja        1         0       0    40   1700.0
# 1              Casa  Lurigancho        2         0       1   100   7000.0
# 3      Departamento  Pachacámac        1         0       0    15    800.0
# 4      Departamento         Ate        1         0       0    48    800.0
# 5      Departamento    Barranco        3         1       0    70   1200.0
# ...             ...         ...      ...       ...     ...   ...      ...
# 32954       Cochera  Pachacámac        0         0       0   755  14000.0
# 32955    Habitación  Pachacámac        0         0       0    27    800.0
# 32956  Departamento       Lince        3         1       2    78   1800.0
# 32957  Departamento       Rímac        2         1       0    48   1400.0
# 32958  Departamento       Rímac        2         0       0    70   3000.0
#
#        Mantenimiento  Impuesto
# 0              500.0      60.0
# 1                NaN       NaN
# 3              390.0      20.0
# 4              230.0       NaN
# 5                NaN       NaN
# ...              ...       ...
# 32954            NaN       NaN
# 32955          350.0      25.0
# 32956          800.0      40.0
# 32957          509.0      37.0
# 32958          760.0       NaN
#
# [23190 rows x 9 columns]

# %%
datos_viviendas.shape
# Out:
# (23190, 9)

# %%
datos_viviendas.index = range(datos_viviendas.shape[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-c08241772603> in <cell line: 1>()
# ----> 1 datos_viviendas.index = range(datos_viviendas.shape[0])
#
# NameError: name 'datos_viviendas' is not defined

# %%
datos_viviendas
# Out:
#                Tipo    Distrito  Cuartos  Vacantes  Suites  Area    Valor  \
# 0        Habitación   San Borja        1         0       0    40   1700.0
# 1              Casa  Lurigancho        2         0       1   100   7000.0
# 2      Departamento  Pachacámac        1         0       0    15    800.0
# 3      Departamento         Ate        1         0       0    48    800.0
# 4      Departamento    Barranco        3         1       0    70   1200.0
# ...             ...         ...      ...       ...     ...   ...      ...
# 23185       Cochera  Pachacámac        0         0       0   755  14000.0
# 23186    Habitación  Pachacámac        0         0       0    27    800.0
# 23187  Departamento       Lince        3         1       2    78   1800.0
# 23188  Departamento       Rímac        2         1       0    48   1400.0
# 23189  Departamento       Rímac        2         0       0    70   3000.0
#
#        Mantenimiento  Impuesto
# 0              500.0      60.0
# 1                NaN       NaN
# 2              390.0      20.0
# 3              230.0       NaN
# 4                NaN       NaN
# ...              ...       ...
# 23185            NaN       NaN
# 23186          350.0      25.0
# 23187          800.0      40.0
# 23188          509.0      37.0
# 23189          760.0       NaN
#
# [23190 rows x 9 columns]

# %%
datos_viviendas.to_csv('alquileres_viviendas.csv', sep = ';')
